# %% [markdown]
# <a href="https://colab.research.google.com/github/Tamil-networks/OIBSIP_domain_taskno.1/blob/main/task_1_datascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries :
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#Load The Dataset :
df=pd.read_csv("/content/Iris.csv")
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Last 5 rows :
df.tail(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#Statistical information :
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#DataFrame information :
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#return a class labels containing counts of yhe unique values :
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
#check null values :
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#remove Id coloum :
df.drop('Id', axis=1, inplace=True)

# %%
#Exploratory Data Analysis :
#pairplot :
sns.pairplot(df, hue='Species')

# %%
#Histogram :
#Histogram of SepalLenght :
df['SepalLengthCm'].hist(grid=False , figsize=(6,4), color='#86bf91', rwidth=0.9)
# Out:
# <Axes: >

# %%
#Histogram of SepalWidth :
df['SepalWidthCm'].hist(grid=False , figsize=(6,4), color='#005fe1', rwidth=0.9)
# Out:
# <Axes: >

# %%
#Histogram of PetalLength :
df['PetalLengthCm'].hist(grid=False , figsize=(6,4), color='#e24a33', rwidth=0.9)
# Out:
# <Axes: >

# %%
#Histogram of PetalWidth :
df['PetalWidthCm'].hist(grid=False , figsize=(6,4), color='#e4e300', rwidth=0.9)
# Out:
# <Axes: >

# %%
#Scatterplot :
colors=['red', 'orange', 'blue']
species=['Iris-virginica', 'Iris-versicolor','Iris-setosa']

# %%
#Scatterplot of Species-sepal lenght and sepal width:
for i in range(3):
       x=df[df['Species']== species[i] ]
       plt. scatter(x['SepalLengthCm'], x['SepalWidthCm'], c=colors[i], label=species [i])
       plt. xlabel('SepalLengthCm')
       plt. ylabel('SepalWidthCm')
       plt. legend()
       plt. show()

# %%
#Scatterplot of Species-petal length and petal width :
for i in range(3):
       x=df[df['Species']== species[i] ]
       plt. scatter(x['PetalLengthCm'], x['PetalWidthCm'], c=colors[i], label=species [i])
       plt. xlabel('PetalLengthCm')
       plt. ylabel('PetalWidthCm')
       plt. legend()
       plt. show()

# %%
#Scattarplot of Species-sepal length and petal length :
for i in range(3):
       x=df[df['Species']== species[i] ]
       plt. scatter(x['SepalLengthCm'], x['PetalLengthCm'], c=colors[i], label=species [i])
       plt. xlabel('SepalLengthCm')
       plt. ylabel('PetalLengthCm')
       plt. legend()
       plt. show()

# %%
#Scatterplot of Species-sepal width and petal width:
for i in range(3):
       x=df[df['Species']== species[i] ]
       plt. scatter(x['SepalWidthCm'], x['PetalWidthCm'], c=colors[i], label=species [i])
       plt. xlabel('SepalWidthCm')
       plt. ylabel('PetalWidthCm')
       plt. legend()
       plt. show()

# %%
#Boxplots :
#Boxplot of sepal length :
sns.boxplot(y='SepalLengthCm', data=df)
# Out:
# <Axes: ylabel='SepalLengthCm'>

# %%
#Boxplots of sepal width :
sns.boxplot(y='SepalWidthCm', data=df)
# Out:
# <Axes: ylabel='SepalWidthCm'>

# %%
#Boxplot of petal length :
sns.boxplot(y='PetalLengthCm', data=df)
# Out:
# <Axes: ylabel='PetalLengthCm'>

# %%
#Boxplot of petal width :
sns.boxplot(y='PetalWidthCm', data=df)
# Out:
# <Axes: ylabel='PetalWidthCm'>

# %%
#Boxplot of Species-sepal length :
sns.boxplot(x='Species', y='SepalLengthCm', data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
#Boxplot of Species-sepal width :
sns.boxplot(x='Species', y='SepalWidthCm', data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
#Boxplot of Species-petal length :
sns.boxplot(x='Species', y='PetalLengthCm', data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
#Boxplot of Species-petal width :
sns.boxplot(x='Species', y='PetalWidthCm', data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
#Correlation Matrix :
# Exclude the 'Species' column as it is not numerical
numeric_df = df.drop('Species', axis=1)
corr = numeric_df.corr()
fig, ax=plt.subplots(figsize=(8,6)) # Increased figure size for better readability
sns.heatmap(corr, annot=True, ax=ax,cmap='RdBu')
plt.title('Correlation Matrix of Iris Dataset (excluding Species)') # Added a title
plt.show() # Explicitly show the plot

# %%
#Label Encode :
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Species ']=le.fit_transform(df['Species'])
df. head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
#
#    Species
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
#Model Training :
#Splitting the dataset into training  and testing :
from sklearn.model_selection import train_test_split

x=df. drop(columns=['Species'])
y=df['Species']
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2)

# %%
# Selecting the supervised machine learning models:
from sklearn.linear_model  import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
LR=LogisticRegression(solver='lbfgs',max_iter=1000)
KNN=KNeighborsClassifier()
SVC=SVC()
GNB=GaussianNB()
DTC=DecisionTreeClassifier()
RCF=RandomForestClassifier()

# %%
#Training and Evaluating models :
models=[LR, KNN, SVC, GNB, DTC, RCF]

for model in models:
    model.fit(x_train, y_train)
    prediction=model.predict(x_test)

    print(f'Accuracy of {type(model).__name__} is {round(accuracy_score(y_test, prediction)*100, 2)}%')
# Out:
# Accuracy of LogisticRegression is 100.0%
# Accuracy of KNeighborsClassifier is 100.0%
# Accuracy of SVC is 100.0%
# Accuracy of GaussianNB is 100.0%
# Accuracy of DecisionTreeClassifier is 100.0%
# Accuracy of RandomForestClassifier is 100.0%
